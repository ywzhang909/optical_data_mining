# %%
import pandas as pd

# %% [markdown]
# # Loading exp data

# %%
exp_df = pd.read_excel('../data/实验记录v20251230+数字光学+大气v20251230.xlsx', index_col='序号')
exp_df

# %%
do_df = pd.read_excel('../data/digital_optical_arch.xlsx')
do_df

# %% [markdown]
# # 相关性分析

# %%
exp_df['作用时间(s)'] = exp_df['作用时间'].str.replace('s', '').astype(float)
exp_df['厚度(mm)'] = exp_df['厚度'].apply(lambda x: x.replace('mm', '')).astype(float)
exp_df
